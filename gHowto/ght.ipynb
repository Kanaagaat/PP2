# %% [markdown]
# ** Creating folder for GitHowTo report**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Enter by username and email**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **creatin git repositories**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Creating html file and ccomitting it**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **To check status of repositories**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Making changes in hello.html file and work with git status**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **As we changed file we should index file and commit it**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Changes, not files. First we added standart tags in hello.html file and indexed in repositories. Secondly making another changes by adding head tags.

# %%
<html>
  <body>
    <h1>Hello, World!</h1>
  </body>
</html>
_________________________________________
<html>
  <head>
  </head>
  <body>
    <h1>Hello, World!</h1>
  </body>
</html>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **History**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Taking old versions**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Creating tags for version**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Reseting changes**

# %% [markdown]
# ![image.png](attachment:image.png)
